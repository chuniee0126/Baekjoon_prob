# %%
def result(N):
    if N/5 != 0:
        if (N%5)%3 == 0:
            print N/5 + (N%5)/3
        elif (N%5) == 1 or (N%5) == 4 :
            print (N-5)/5 + (N%5 + 5)/3
        elif (N%5) == 2:
            if N/5 != 1:
                print (N-10)/5 + (N%5 + 10)/3
            else :
                print -1
    else:
        if N%3 == 0:
            print N/3
        else :
            print -1

result(input())
# Out:
# 22
# 6
